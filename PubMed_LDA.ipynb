# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, PCA
from sklearn.cluster import KMeans

import pandas as pd
import nltk
import nltk.data

# %%
df = 'captions.txt'


tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
fp = open("captions.txt")
data = fp.read()

df ='\n\n'.join(tokenizer.tokenize(data))

df = df.split("\n\n")

# %%
import pandas as pd
df=pd.DataFrame(df)
df=df[0].str.replace('[^A-Za-z0-9.]+', ' ')

# %%
import PyPDF2
import csv

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from gensim import corpora
from gensim.models import LdaModel

import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, PCA
from sklearn.cluster import KMeans

import pyLDAvis.gensim

def biphrase_process(tokens, deacc=True, lowercase=True, errors='ignore',
    stemmer=None, stopwords=None):

    bigrams = []

    if len(tokens) >1:
        for i in range(0,len(tokens)-1):
            yield tokens[i] + '_' + tokens[i+1]

#nltk.download()

# %%
df 

documents = df

from sklearn.feature_extraction import stop_words

stop = list(stop_words.ENGLISH_STOP_WORDS)
banned = ["et al", "m.", "et_al", "_", "", "us", "go", "also", "lot", "'s", "'re", "n't", "'m", "going", "--_--", "—", "--", "'ve", "ve"]

banned_total = set(stop + banned)

texts = [word_tokenize(doc)  for doc in documents]
texts_lower = [[word.lower() for word in text] for text in texts]
uniphrases = [[word for word in text if not word.isdigit() and word not in banned_total and len(word) > 1] for text in texts_lower]

biphrases = [[biphrase for biphrase in biphrase_process(text)] for text in uniphrases]

dictionary_biphrases = corpora.Dictionary(biphrases, prune_at=20000000)
dictionary_biphrases.save_as_text('gensim_dict_biphrases.txt')

# %%
corpus = [dictionary_biphrases.doc2bow(text) for text in biphrases]
lda = LdaModel(corpus, num_topics=4, id2word=dictionary_biphrases)

pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(lda, corpus, dictionary_biphrases)
# Out:
# /Users/B.Patel@ibm.com/anaconda2/lib/python2.7/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      25.878848        1       1 -0.098789 -0.138542
# 0      25.391942        1       2 -0.099888  0.138066
# 3      25.195313        1       3  0.091152 -0.003268
# 1      23.533897        1       4  0.107525  0.003744, topic_info=       Category         Freq                        Term        Total  \
# term
# 616129  Default  1315.000000     independent_experiments  1315.000000
# 120644  Default  1144.000000                   wild_type  1144.000000
# 717367  Default   990.000000                  error_bars   990.000000
# 414359  Default   919.000000                   0.05_0.01   919.000000
# 50973   Default   783.000000                       et_al   783.000000
# 900318  Default   828.000000              bars_represent   828.000000
# 603730  Default   812.000000               control_group   812.000000
# 691547  Default   772.000000                western_blot   772.000000
# 612659  Default   759.000000                    mean_sem   759.000000
# 628779  Default   729.000000               cells_treated   729.000000
# 882439  Default   612.000000      significant_difference   612.000000
# 969884  Default   592.000000                  mice_group   592.000000
# 969572  Default   576.000000              mice_immunized   576.000000
# 120085  Default   571.000000              flow_cytometry   571.000000
# 648218  Default   561.000000          standard_deviation   561.000000
# 8463    Default   539.000000                     mean_sd   539.000000
# 710915  Default   523.000000                   way_anova   523.000000
# 150367  Default   511.000000     significantly_different   511.000000
# 524116  Default   507.000000                  0.01_0.001   507.000000
# 57320   Default   474.000000                   scale_bar   474.000000
# 657613  Default   480.000000     significant_differences   480.000000
# 45284   Default   461.000000                      rt_pcr   461.000000
# 531002  Default   448.000000            negative_control   448.000000
# 571614  Default   445.000000              represent_mean   445.000000
# 12812   Default   431.000000           cells_transfected   431.000000
# 50281   Default   425.000000              standard_error   425.000000
# 179845  Default   423.000000               bars_indicate   423.000000
# 473807  Default   422.000000   statistically_significant   422.000000
# 603792  Default   393.000000  representative_independent   393.000000
# 785471  Default   417.000000              data_presented   417.000000
# ...         ...          ...                         ...          ...
# 141584   Topic4   203.871838       experiments_performed   204.376902
# 328998   Topic4   201.797079      original_magnification   202.303880
# 617453   Topic4   173.450225             similar_results   173.943666
# 509740   Topic4   178.397934             represents_mean   178.912023
# 109014   Topic4   175.488939                  shown_mean   176.001459
# 98324    Topic4   187.947259             cells_incubated   188.502531
# 128082   Topic4   172.041161                figure_shows   172.552117
# 785251   Topic4   177.876444            cells_expressing   178.425035
# 413200   Topic4   148.906376           experiments_shown   149.404329
# 291817   Topic4   150.740430               meta_analysis   151.246771
# 951076   Topic4   141.235480  representative_experiments   141.735712
# 265310   Topic4   146.037833              control_groups   146.569440
# 151780   Topic4   132.977094        shown_representative   133.478620
# 227305   Topic4   145.595946               treated_group   146.146863
# 760298   Topic4   132.159952                    means_sd   132.662565
# 80683    Topic4   125.586897                 data_points   126.100335
# 459414   Topic4   151.691119            treatment_groups   152.321484
# 786381   Topic4   120.296017                  cell_cycle   120.802433
# 901141   Topic4   120.025654   representative_experiment   120.531873
# 878040   Topic4   122.652390            indicated_arrows   123.170275
# 507697   Topic4   120.313742             arrow_indicates   120.825206
# 506211   Topic4   135.828135                  c57bl_mice   136.416291
# 534831   Topic4   127.279729         monoclonal_antibody   127.858973
# 541980   Topic4   125.250942                 lung_cancer   125.802556
# 616129   Topic4  1274.168289     independent_experiments  1315.441836
# 570674   Topic4   181.787769            antigen_specific   183.745003
# 859775   Topic4   154.040698                   mice_days   155.275466
# 926379   Topic4   407.302940                  time_point   458.861205
# 381445   Topic4   143.830665              sd_independent   146.962125
# 682318   Topic4   133.360209               growth_factor   134.822562
#
#         loglift  logprob
# term
# 616129  30.0000  30.0000
# 120644  29.0000  29.0000
# 717367  28.0000  28.0000
# 414359  27.0000  27.0000
# 50973   26.0000  26.0000
# 900318  25.0000  25.0000
# 603730  24.0000  24.0000
# 691547  23.0000  23.0000
# 612659  22.0000  22.0000
# 628779  21.0000  21.0000
# 882439  20.0000  20.0000
# 969884  19.0000  19.0000
# 969572  18.0000  18.0000
# 120085  17.0000  17.0000
# 648218  16.0000  16.0000
# 8463    15.0000  15.0000
# 710915  14.0000  14.0000
# 150367  13.0000  13.0000
# 524116  12.0000  12.0000
# 57320   11.0000  11.0000
# 657613  10.0000  10.0000
# 45284    9.0000   9.0000
# 531002   8.0000   8.0000
# 571614   7.0000   7.0000
# 12812    6.0000   6.0000
# 50281    5.0000   5.0000
# 179845   4.0000   4.0000
# 473807   3.0000   3.0000
# 603792   2.0000   2.0000
# 785471   1.0000   1.0000
# ...         ...      ...
# 141584   1.4443  -7.6431
# 328998   1.4442  -7.6533
# 617453   1.4439  -7.8047
# 509740   1.4439  -7.7766
# 109014   1.4438  -7.7930
# 98324    1.4438  -7.7244
# 128082   1.4438  -7.8128
# 785251   1.4436  -7.7795
# 413200   1.4434  -7.9573
# 291817   1.4434  -7.9450
# 951076   1.4432  -8.0101
# 265310   1.4431  -7.9767
# 151780   1.4430  -8.0704
# 227305   1.4430  -7.9797
# 760298   1.4429  -8.0766
# 80683    1.4426  -8.1276
# 459414   1.4426  -7.9387
# 786381   1.4425  -8.1706
# 901141   1.4425  -8.1729
# 878040   1.4425  -8.1512
# 507697   1.4425  -8.1705
# 506211   1.4424  -8.0492
# 534831   1.4422  -8.1142
# 541980   1.4423  -8.1303
# 616129   1.4148  -5.8105
# 570674   1.4360  -7.7577
# 859775   1.4387  -7.9234
# 926379   1.3275  -6.9510
# 381445   1.4252  -7.9919
# 682318   1.4358  -8.0675
#
# [182 rows x 6 columns], token_table=        Topic      Freq                       Term
# term
# 524116      1  0.999501                 0.01_0.001
# 414359      1  0.999620                  0.05_0.01
# 260880      1  0.999957              0.05_compared
# 26902       4  0.996147                0.05_versus
# 706418      1  0.999610                   0.05_vs.
# 878933      3  0.997460               adjusted_age
# 887197      3  0.995627                    age_sex
# 51205       3  0.998897                 amino_acid
# 570674      2  0.005442           antigen_specific
# 570674      4  0.990503           antigen_specific
# 507697      4  0.993170            arrow_indicates
# 585885      3  0.999374            arrows_indicate
# 232775      2  0.996279             bar_represents
# 179845      1  0.999179              bars_indicate
# 900318      1  0.999421             bars_represent
# 432098      2  0.997220              blot_analysis
# 147762      3  0.997145                bone_marrow
# 99027       2  0.997540              breast_cancer
# 506211      4  0.996948                 c57bl_mice
# 572129      1  0.142504                  cd4_cells
# 572129      2  0.855022                  cd4_cells
# 975168      1  0.057050                   cd8_cell
# 975168      2  0.941326                   cd8_cell
# 904858      1  0.489840                  cd8_cells
# 904858      2  0.509902                  cd8_cells
# 786381      4  0.993357                 cell_cycle
# 818535      1  0.008033                  cell_line
# 818535      3  0.992098                  cell_line
# 826527      2  0.716067                 cell_lines
# 826527      3  0.283611                 cell_lines
# ...       ...       ...                        ...
# 150367      1  0.998516    significantly_different
# 142825      3  0.998358       significantly_higher
# 213936      3  0.997724        significantly_lower
# 617453      4  0.994575            similar_results
# 805903      2  0.999178                 solid_line
# 648218      1  0.999693         standard_deviation
# 50281       1  0.999221             standard_error
# 473807      1  0.999069  statistically_significant
# 200244      1  0.999832              students_test
# 490448      3  0.997254               study_design
# 411218      3  0.998804            survival_curves
# 347047      1  0.005300          thyroid_carcinoma
# 347047      3  0.996391          thyroid_carcinoma
# 335942      3  0.999195                time_course
# 926379      1  0.111145                 time_point
# 926379      4  0.886978                 time_point
# 65643       2  0.414453                time_points
# 65643       3  0.585497                time_points
# 468130      3  0.998181                 time_spent
# 569435      1  0.005221              treated_cells
# 569435      2  0.991993              treated_cells
# 227305      4  0.998995              treated_group
# 639073      3  0.998563            treatment_group
# 459414      4  0.997889           treatment_groups
# 876243      1  0.998081                tumor_cells
# 710915      1  0.999877                  way_anova
# 691547      2  0.998882               western_blot
# 801459      1  0.003403           western_blotting
# 801459      2  0.997084           western_blotting
# 120644      1  0.999924                  wild_type
#
# [177 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 4, 2])
